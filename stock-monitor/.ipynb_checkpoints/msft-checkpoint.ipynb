# %%
# import packages
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf
from datetime import datetime, date, timedelta

# %%
def getPrice(ticker, interval='1h', backdays=100):

    tick= yf.Ticker(ticker)
    
    print(tick.info.get('shortName'))

    return yf.download(ticker,
                       start=date.today() - timedelta(days=backdays), 
                       end=date.today(),
                       interval=interval,
                       progress=False)

# %%
def predict(ticker):
    interval='15m' # Valid intervals: [1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]
    backdays=2
    df = getPrice(ticker, interval, backdays)
    
    # MFI (money flow index)
    look_back_period = 8  
    
    # Calculate typical price for each day
    df['Typical Price'] = (df['Open']+df['High'] + df['Low'] + df['Close']) / 4
    
    # Calculate raw money flow (RMF)
    df['Raw Money Flow'] = df['Typical Price'] * df['Volume']
    
    # Calculate the money flow ratio (MFR)
    positive_money_flow = (df['Typical Price'] > df['Typical Price'].shift(1))*1*df['Raw Money Flow']
    negative_money_flow = (df['Typical Price'] < df['Typical Price'].shift(1))*1*df['Raw Money Flow']
    mfr = positive_money_flow.rolling(window=look_back_period).sum() / negative_money_flow.rolling(window=look_back_period).sum()
    
    # Calculate the Money Flow Index (MFI)
    mfi = 100 - (100 / (1 + mfr))
    
    # Add the MFI column to the DataFrame
    df['MFI'] = mfi

    # calculate confidence
    # linear interpolation between MFI 30 and 70
    # Sell when the MFI rises above 70 as it indicates an overbought condition and buy when the MFI falls below 30 as it indicates an oversold condition.
    # at MFI=30, confidence=100 to buy, at MFI=70, confidence=-100 
    # confidence = (-5)*MFI + 250

    # waited MFI to include past 3 MFI
    weighted_mfi = (df['MFI'].iloc[-1]*(4)+df['MFI'].iloc[-2]*(3)+df['MFI'].iloc[-3]*(2) + df['MFI'].iloc[-4]*(1))/10

    print(df.MFI.tail(4))
    
    confidence = weighted_mfi*(-5) + 250

    if confidence > 100: 
        confidence=100
        
    if confidence < -100: 
        confidence=-100
    

    print(weighted_mfi)

    if confidence>40:
        print(f'BUY : with Confidence {confidence}')
    elif confidence<-40:
        print(f'SELL : with Confidence {abs(confidence)}')
    else:
        print(f'HOLD : with Confidence {abs(confidence)}')

# %%
nse= 'MSFT'
# lse='BRWM.L'
predict(nse)
# predict(lse)
# Out:
# Microsoft Corporation
# Datetime
# 2023-10-05 15:00:00    80.945672
# 2023-10-05 15:15:00    78.210945
# 2023-10-05 15:30:00    77.975211
# 2023-10-05 15:45:00    86.109379
# Name: MFI, dtype: float64
# 81.57307121502149
# SELL : with Confidence 100

# %%
x=yf.Ticker('BRWM.L')
x.info
# Out:
# {'address1': '33 King William Street',
#  'city': 'London',
#  'zip': 'EC4R 9AS',
#  'country': 'United Kingdom',
#  'phone': '011 44 020 7743 2253',
#  'fax': '011 44 020 7743 1000',
#  'website': 'https://www.blackrock.co.uk/individual/products/investment-trust/blackrock-world-mining-trust',
#  'industry': 'Asset Management',
#  'industryKey': 'asset-management',
#  'industryDisp': 'Asset Management',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'BlackRock World Mining Trust plc is a closed-ended equity mutual fund launched by BlackRock Fund Managers Limited. It is managed by BlackRock Investment Management (UK) Limited. The fund invests in public equity markets across the globe. It seeks to invest in stocks of companies operating in the mining and metal sectors. The fund benchmarks the performance of its portfolio against the Euromoney Global Mining Index. It was formerly known as Merrill Lynch World Mining Trust PLC. BlackRock World Mining Trust plc was formed on December 15, 1993 and is domiciled in the United Kingdom.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. J. Richard Kushel',
#    'age': 55,
#    'title': 'Vie Chairman',
#    'yearBorn': 1967,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Evy Piers George Hambro',
#    'title': 'Portfolio Mang.',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Olivia  Markham',
#    'title': 'Portfolio Mang.',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 541.0,
#  'open': 0.0,
#  'dayLow': 0.0,
#  'dayHigh': 0.0,
#  'regularMarketPreviousClose': 541.0,
#  'regularMarketOpen': 0.0,
#  'regularMarketDayLow': 0.0,
#  'regularMarketDayHigh': 0.0,
#  'dividendRate': 0.4,
#  'dividendYield': 0.069,
#  'exDividendDate': 1694044800,
#  'payoutRatio': 0.5795,
#  'fiveYearAvgDividendYield': 5.36,
#  'beta': 1.098723,
#  'trailingPE': 7.9130435,
#  'volume': 134758,
#  'regularMarketVolume': 134758,
#  'averageVolume': 309159,
#  'averageVolume10days': 433080,
#  'averageDailyVolume10Day': 433080,
#  'bid': 0.0,
#  'ask': 640.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 1065458944,
#  'fiftyTwoWeekLow': 0.0,
#  'fiftyTwoWeekHigh': 775.0,
#  'priceToSalesTrailing12Months': 7.462974,
#  'fiftyDayAverage': 589.64,
#  'twoHundredDayAverage': 646.255,
#  'trailingAnnualDividendRate': 0.4,
#  'trailingAnnualDividendYield': 0.0007393715,
#  'currency': 'GBp',
#  'enterpriseValue': 1237918720,
#  'profitMargins': 0.8926,
#  'sharesOutstanding': 191183008,
#  'heldPercentInsiders': 0.0627,
#  'heldPercentInstitutions': 0.1075,
#  'impliedSharesOutstanding': 195139008,
#  'bookValue': 6.127,
#  'priceToBook': 89.11376,
#  'lastFiscalYearEnd': 1672444800,
#  'nextFiscalYearEnd': 1703980800,
#  'mostRecentQuarter': 1688083200,
#  'netIncomeToCommon': 127433000,
#  'trailingEps': 0.69,
#  'enterpriseToRevenue': 8.671,
#  '52WeekChange': -0.08149403,
#  'SandP52WeekChange': 0.16994166,
#  'lastDividendValue': 0.055,
#  'lastDividendDate': 1694044800,
#  'exchange': 'LSE',
#  'quoteType': 'EQUITY',
#  'symbol': 'BRWM.L',
#  'underlyingSymbol': 'BRWM.L',
#  'shortName': 'BLACKROCK WORLD MINING TRUST PL',
#  'longName': 'BlackRock World Mining Trust plc',
#  'firstTradeDateEpochUtc': 755942400,
#  'timeZoneFullName': 'Europe/London',
#  'timeZoneShortName': 'BST',
#  'uuid': 'a5b6e75c-c7c1-3bf4-b4c2-58e49c24ad88',
#  'messageBoardId': 'finmb_4509970',
#  'gmtOffSetMilliseconds': 3600000,
#  'currentPrice': 546.0,
#  'recommendationMean': 3.0,
#  'recommendationKey': 'hold',
#  'totalCash': 42207000,
#  'totalCashPerShare': 0.221,
#  'totalDebt': 150234000,
#  'quickRatio': 0.294,
#  'currentRatio': 0.294,
#  'totalRevenue': 142766000,
#  'debtToEquity': 12.825,
#  'revenuePerShare': 0.754,
#  'returnOnAssets': 0.06258,
#  'returnOnEquity': 0.112229995,
#  'grossProfits': 239744000,
#  'freeCashflow': 73938496,
#  'operatingCashflow': 73852000,
#  'grossMargins': 1.0,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': 0.92021006,
#  'financialCurrency': 'GBP',
#  'trailingPegRatio': None}
